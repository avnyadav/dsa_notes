# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![https://d3i71xaburhd42.cloudfront.net/161ca0f4ea0224cef9b387aef1b750fb71324b60/2-Table1-1.png]()

# %%
from os import *
from sys import *
from collections import *
from math import *

def selectionSort(arr,n):
    # Write your code here
    # Do not return anything. Update the given array in-place

    for i in range(n-1):
        minIdx=i
        for j in range(i,n):
            if arr[j]<arr[minIdx]:
                minIdx=j
        
        arr[i],arr[minIdx]=arr[minIdx],arr[i]
